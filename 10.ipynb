# %%
# 전체 파이프라인 코드 (YOLOv8 필터링 + TensorFlow 학습 및 추론)
import os
import random
import numpy as np
import pandas as pd
from glob import glob
from tqdm import tqdm
from sklearn.model_selection import StratifiedKFold

import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.efficientnet import preprocess_input

import cv2
from ultralytics import YOLO

# -----------------------
# GPU 확인
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print(f"[INFO] {len(gpus)} GPU(s) available: {[gpu.name for gpu in gpus]}")
else:
    print("[INFO] No GPU available. Training will use CPU.")

# -----------------------
# Config
CFG = {
    'IMG_SIZE': 224,
    'EPOCHS': 15,
    'LR': 3e-4,
    'BATCH_SIZE': 24,
    'SEED': 2025,
    'FOLDS': 5
}

# Seed 고정
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)

set_seed(CFG['SEED'])

# -----------------------
# 경로 설정
ORIGINAL_TRAIN_DIR = "D:/데이콘 250519 대회/open/train"
FILTERED_TRAIN_DIR = "D:/데이콘 250519 대회/filtered_train"
TEST_DIR = "D:/데이콘 250519 대회/open/test"
SAMPLE_SUB = "D:/데이콘 250519 대회/open/sample_submission.csv"

# -----------------------
# YOLOv8 차량 외관 필터링 함수

VEHICLE_CLASSES = [2, 5, 7]  # car, bus, truck 클래스 번호

yolo_model = YOLO('yolov8n.pt')  # 또는 yolov8s.pt

def is_full_vehicle(detections, img):
    h, w = img.shape[:2]
    img_area = h * w

    for det in detections:
        cls = int(det.cls)
        if cls not in VEHICLE_CLASSES:
            continue

        x1, y1, x2, y2 = det.xyxy[0].cpu().numpy()
        box_w, box_h = x2 - x1, y2 - y1
        area = box_w * box_h
        center_x, center_y = (x1 + x2) / 2, (y1 + y2) / 2
        aspect_ratio = box_w / box_h

        # 중앙에 위치하고, 큰 크기의 차량이 1개 이상 감지된 경우만 채택
        if not (0.3 * w < center_x < 0.7 * w and 0.3 * h < center_y < 0.7 * h):
            continue
        if area / img_area < 0.35:
            continue
        if aspect_ratio < 0.9 or aspect_ratio > 2.2:
            continue
        return True

    return False

# -----------------------
# 차량 외관 필터링 수행

print("차량 외관 이상치 필터링 시작...")
os.makedirs(FILTERED_TRAIN_DIR, exist_ok=True)
class_dirs = sorted(os.listdir(ORIGINAL_TRAIN_DIR))

filtered_count = 0
total_count = 0

for cls in tqdm(class_dirs, desc="클래스별 필터링"):
    input_dir = os.path.join(ORIGINAL_TRAIN_DIR, cls)
    output_dir = os.path.join(FILTERED_TRAIN_DIR, cls)
    os.makedirs(output_dir, exist_ok=True)

    image_paths = glob(os.path.join(input_dir, "*.jpg"))
    for img_path in image_paths:
        total_count += 1
        img = cv2.imread(img_path)
        results = yolo_model(img, verbose=False)[0]

        if is_full_vehicle(results.boxes, img):
            filename = os.path.basename(img_path)
            cv2.imwrite(os.path.join(output_dir, filename), img)
            filtered_count += 1

print(f"🔍 전체 이미지 수: {total_count}")
print(f"✅ 필터링된 차량 외관 이미지 수: {filtered_count}")
print(f"🧼 이상치 제거 완료. 정제 비율: {filtered_count / total_count:.2%}")

# -----------------------
# 학습 데이터 준비

label_list = sorted(os.listdir(FILTERED_TRAIN_DIR))
label2id = {v: i for i, v in enumerate(label_list)}
id2label = {i: v for v, i in label2id.items()}

image_paths = glob(os.path.join(FILTERED_TRAIN_DIR, '*', '*.jpg'))
labels = [label2id[os.path.basename(os.path.dirname(p))] for p in image_paths]

# -----------------------
# 데이터 전처리 함수

def load_and_preprocess(img_path):
    img = load_img(img_path, target_size=(CFG['IMG_SIZE'], CFG['IMG_SIZE']))
    img = img_to_array(img)
    img = preprocess_input(img)
    return img

def create_dataset(image_paths, labels=None, is_train=True):
    def gen():
        for i, path in enumerate(image_paths):
            img = load_and_preprocess(path)
            if labels is not None:
                yield img, labels[i]
            else:
                yield img

    if labels is not None:
        ds = tf.data.Dataset.from_generator(
            gen,
            output_types=(tf.float32, tf.int32),
            output_shapes=((CFG['IMG_SIZE'], CFG['IMG_SIZE'], 3), ())
        )
    else:
        ds = tf.data.Dataset.from_generator(
            gen,
            output_types=tf.float32,
            output_shapes=(CFG['IMG_SIZE'], CFG['IMG_SIZE'], 3)
        )

    if is_train:
        ds = ds.shuffle(1024)
    ds = ds.batch(CFG['BATCH_SIZE']).prefetch(tf.data.AUTOTUNE)
    return ds

# -----------------------
# 모델 생성

def build_model(num_classes):
    base = tf.keras.applications.EfficientNetB0(
        include_top=False,
        input_shape=(CFG['IMG_SIZE'], CFG['IMG_SIZE'], 3),
        weights='imagenet',
        pooling='avg'
    )
    x = layers.Dense(num_classes, activation='softmax')(base.output)
    model = models.Model(inputs=base.input, outputs=x)
    return model

# -----------------------
# Stratified K-Fold 학습

skf = StratifiedKFold(n_splits=CFG['FOLDS'], shuffle=True, random_state=CFG['SEED'])

for fold, (train_idx, val_idx) in enumerate(skf.split(image_paths, labels)):
    print(f"\n### Fold {fold+1} 시작 ###")

    train_paths = [image_paths[i] for i in train_idx]
    val_paths = [image_paths[i] for i in val_idx]
    train_labels = [labels[i] for i in train_idx]
    val_labels = [labels[i] for i in val_idx]

    train_ds = create_dataset(train_paths, train_labels, is_train=True)
    val_ds = create_dataset(val_paths, val_labels, is_train=False)

    model = build_model(num_classes=len(label2id))
    model.compile(
        optimizer=optimizers.Adam(CFG['LR']),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=CFG['EPOCHS'],
        verbose=1
    )

# -----------------------
# 테스트 데이터 추론 및 제출 파일 생성

test_paths = sorted(glob(os.path.join(TEST_DIR, '*.jpg')))
test_ds = create_dataset(test_paths, is_train=False)

print("테스트 데이터 추론 시작...")
preds = model.predict(test_ds)
print("추론 완료")

submission = pd.read_csv(SAMPLE_SUB)
for idx, class_name in enumerate(label2id.keys()):
    submission[class_name] = preds[:, idx]

submission.to_csv("submission.csv", index=False)
print("submission.csv 저장 완료")
# Out:
# [INFO] 1 GPU(s) available: ['/physical_device:GPU:0']
# 차량 외관 이상치 필터링 시작...
# 클래스별 필터링: 100%|██████████| 396/396 [32:37<00:00,  4.94s/it]
# 🔍 전체 이미지 수: 33137
# ✅ 필터링된 차량 외관 이미지 수: 29663
# 🧼 이상치 제거 완료. 정제 비율: 89.52%
#
# ### Fold 1 시작 ###
# Epoch 1/15
# 989/989 [==============================] - 488s 201ms/step - loss: 2.9322 - accuracy: 0.4328 - val_loss: 4.2578 - val_accuracy: 0.2006
# Epoch 2/15
# 989/989 [==============================] - 86s 85ms/step - loss: 0.9200 - accuracy: 0.7466 - val_loss: 2.5478 - val_accuracy: 0.3774
# Epoch 3/15
# 989/989 [==============================] - 88s 87ms/step - loss: 0.4277 - accuracy: 0.8713 - val_loss: 1.8510 - val_accuracy: 0.5008
# Epoch 4/15
# 989/989 [==============================] - 88s 87ms/step - loss: 0.2733 - accuracy: 0.9199 - val_loss: 1.4984 - val_accuracy: 0.5983
# Epoch 5/15
# 989/989 [==============================] - 89s 88ms/step - loss: 0.1900 - accuracy: 0.9451 - val_loss: 1.3964 - val_accuracy: 0.6196
# Epoch 6/15
# 989/989 [==============================] - 85s 84ms/step - loss: 0.1463 - accuracy: 0.9577 - val_loss: 1.2083 - val_accuracy: 0.6909
# Epoch 7/15
# 989/989 [==============================] - 86s 85ms/step - loss: 0.1227 - accuracy: 0.9639 - val_loss: 1.1057 - val_accuracy: 0.7194
# Epoch 8/15
# 989/989 [==============================] - 89s 87ms/step - loss: 0.1044 - accuracy: 0.9705 - val_loss: 1.0165 - val_accuracy: 0.7394
# Epoch 9/15
# 989/989 [==============================] - 86s 85ms/step - loss: 0.0880 - accuracy: 0.9757 - val_loss: 0.8924 - val_accuracy: 0.7728
# Epoch 10/15
# 989/989 [==============================] - 85s 84ms/step - loss: 0.0737 - accuracy: 0.9802 - val_loss: 0.8227 - val_accuracy: 0.7918
# Epoch 11/15
# 989/989 [==============================] - 86s 85ms/step - loss: 0.0660 - accuracy: 0.9815 - val_loss: 0.9245 - val_accuracy: 0.7785
# Epoch 12/15
# 989/989 [==============================] - 86s 85ms/step - loss: 0.0641 - accuracy: 0.9827 - val_loss: 0.7423 - val_accuracy: 0.8143
# Epoch 13/15
# 989/989 [==============================] - 86s 85ms/step - loss: 0.0583 - accuracy: 0.9847 - val_loss: 0.8722 - val_accuracy: 0.7905
# Epoch 14/15
# 989/989 [==============================] - 86s 85ms/step - loss: 0.0561 - accuracy: 0.9840 - val_loss: 1.0305 - val_accuracy: 0.7549
# Epoch 15/15
# 989/989 [==============================] - 87s 85ms/step - loss: 0.0505 - accuracy: 0.9860 - val_loss: 1.1011 - val_accuracy: 0.7573
#
# ### Fold 2 시작 ###
# Epoch 1/15
# 989/989 [==============================] - 92s 86ms/step - loss: 2.9216 - accuracy: 0.4401 - val_loss: 4.3889 - val_accuracy: 0.1869
# Epoch 2/15
# 989/989 [==============================] - 87s 86ms/step - loss: 0.9282 - accuracy: 0.7452 - val_loss: 2.6415 - val_accuracy: 0.3376
# Epoch 3/15
# 989/989 [==============================] - 87s 86ms/step - loss: 0.4176 - accuracy: 0.8770 - val_loss: 1.7445 - val_accuracy: 0.5206
# Epoch 4/15
# 989/989 [==============================] - 88s 87ms/step - loss: 0.2579 - accuracy: 0.9236 - val_loss: 1.3912 - val_accuracy: 0.6042
# Epoch 5/15
# 989/989 [==============================] - 87s 85ms/step - loss: 0.1874 - accuracy: 0.9447 - val_loss: 1.3467 - val_accuracy: 0.6278
# Epoch 6/15
# 989/989 [==============================] - 87s 86ms/step - loss: 0.1387 - accuracy: 0.9596 - val_loss: 1.0379 - val_accuracy: 0.7099
# Epoch 7/15
# 989/989 [==============================] - 87s 86ms/step - loss: 0.1251 - accuracy: 0.9620 - val_loss: 1.0232 - val_accuracy: 0.7334
# Epoch 8/15
# 989/989 [==============================] - 86s 85ms/step - loss: 0.1004 - accuracy: 0.9713 - val_loss: 1.0105 - val_accuracy: 0.7345
# Epoch 9/15
# 989/989 [==============================] - 85s 84ms/step - loss: 0.0845 - accuracy: 0.9758 - val_loss: 0.9459 - val_accuracy: 0.7548
# Epoch 10/15
# 989/989 [==============================] - 86s 85ms/step - loss: 0.0876 - accuracy: 0.9760 - val_loss: 0.9739 - val_accuracy: 0.7561
# Epoch 11/15
# 989/989 [==============================] - 87s 86ms/step - loss: 0.0706 - accuracy: 0.9803 - val_loss: 1.0507 - val_accuracy: 0.7425
# Epoch 12/15
# 989/989 [==============================] - 88s 87ms/step - loss: 0.0594 - accuracy: 0.9828 - val_loss: 0.8365 - val_accuracy: 0.7890
# Epoch 13/15
# 989/989 [==============================] - 88s 87ms/step - loss: 0.0656 - accuracy: 0.9812 - val_loss: 1.0386 - val_accuracy: 0.7674
# Epoch 14/15
# 989/989 [==============================] - 86s 85ms/step - loss: 0.0583 - accuracy: 0.9844 - val_loss: 0.8881 - val_accuracy: 0.7826
# Epoch 15/15
# 989/989 [==============================] - 88s 87ms/step - loss: 0.0508 - accuracy: 0.9861 - val_loss: 0.7813 - val_accuracy: 0.8121
#
# ### Fold 3 시작 ###
# Epoch 1/15
# 989/989 [==============================] - 118s 112ms/step - loss: 2.8679 - accuracy: 0.4441 - val_loss: 4.2678 - val_accuracy: 0.1927
# Epoch 2/15
# 989/989 [==============================] - 116s 114ms/step - loss: 0.9162 - accuracy: 0.7510 - val_loss: 2.4699 - val_accuracy: 0.3650
# Epoch 3/15
# 989/989 [==============================] - 113s 110ms/step - loss: 0.4078 - accuracy: 0.8788 - val_loss: 1.6353 - val_accuracy: 0.5335
# Epoch 4/15
# 989/989 [==============================] - 98s 96ms/step - loss: 0.2516 - accuracy: 0.9246 - val_loss: 1.3458 - val_accuracy: 0.6202
# Epoch 5/15
# 989/989 [==============================] - 87s 86ms/step - loss: 0.1814 - accuracy: 0.9454 - val_loss: 1.1876 - val_accuracy: 0.6687
# Epoch 6/15
# 989/989 [==============================] - 88s 87ms/step - loss: 0.1389 - accuracy: 0.9589 - val_loss: 1.0181 - val_accuracy: 0.7262
# Epoch 7/15
# 989/989 [==============================] - 88s 86ms/step - loss: 0.1231 - accuracy: 0.9633 - val_loss: 0.9593 - val_accuracy: 0.7448
# Epoch 8/15
# 989/989 [==============================] - 87s 86ms/step - loss: 0.0942 - accuracy: 0.9724 - val_loss: 1.0615 - val_accuracy: 0.7338
# Epoch 9/15
# 989/989 [==============================] - 86s 85ms/step - loss: 0.0913 - accuracy: 0.9737 - val_loss: 0.8626 - val_accuracy: 0.7746
# Epoch 10/15
# 989/989 [==============================] - 88s 87ms/step - loss: 0.0752 - accuracy: 0.9777 - val_loss: 0.8528 - val_accuracy: 0.7889
# Epoch 11/15
# 989/989 [==============================] - 89s 87ms/step - loss: 0.0752 - accuracy: 0.9791 - val_loss: 0.9536 - val_accuracy: 0.7712
# Epoch 12/15
# 989/989 [==============================] - 90s 89ms/step - loss: 0.0624 - accuracy: 0.9824 - val_loss: 0.8992 - val_accuracy: 0.7937
# Epoch 13/15
# 989/989 [==============================] - 93s 91ms/step - loss: 0.0563 - accuracy: 0.9850 - val_loss: 0.8698 - val_accuracy: 0.8007
# Epoch 14/15
# 989/989 [==============================] - 90s 88ms/step - loss: 0.0513 - accuracy: 0.9861 - val_loss: 0.9802 - val_accuracy: 0.7889
# Epoch 15/15
# 989/989 [==============================] - 96s 95ms/step - loss: 0.0525 - accuracy: 0.9849 - val_loss: 0.9447 - val_accuracy: 0.7832
#
# ### Fold 4 시작 ###
# Epoch 1/15
# 989/989 [==============================] - 99s 92ms/step - loss: 2.9200 - accuracy: 0.4434 - val_loss: 4.0269 - val_accuracy: 0.1910
# Epoch 2/15
# 989/989 [==============================] - 91s 90ms/step - loss: 0.9256 - accuracy: 0.7519 - val_loss: 2.4575 - val_accuracy: 0.3759
# Epoch 3/15
# 989/989 [==============================] - 92s 91ms/step - loss: 0.4176 - accuracy: 0.8775 - val_loss: 1.7152 - val_accuracy: 0.5341
# Epoch 4/15
# 989/989 [==============================] - 90s 89ms/step - loss: 0.2614 - accuracy: 0.9220 - val_loss: 1.3693 - val_accuracy: 0.6200
# Epoch 5/15
# 989/989 [==============================] - 92s 90ms/step - loss: 0.1837 - accuracy: 0.9440 - val_loss: 1.3942 - val_accuracy: 0.6340
# Epoch 6/15
# 989/989 [==============================] - 91s 89ms/step - loss: 0.1471 - accuracy: 0.9574 - val_loss: 1.1791 - val_accuracy: 0.6802
# Epoch 7/15
# 989/989 [==============================] - 91s 90ms/step - loss: 0.1203 - accuracy: 0.9656 - val_loss: 1.0715 - val_accuracy: 0.7323
# Epoch 8/15
# 989/989 [==============================] - 91s 89ms/step - loss: 0.1049 - accuracy: 0.9686 - val_loss: 0.8107 - val_accuracy: 0.7814
# Epoch 9/15
# 989/989 [==============================] - 92s 90ms/step - loss: 0.0829 - accuracy: 0.9778 - val_loss: 0.8072 - val_accuracy: 0.7805
# Epoch 10/15
# 989/989 [==============================] - 95s 93ms/step - loss: 0.0730 - accuracy: 0.9800 - val_loss: 0.8051 - val_accuracy: 0.7901
# Epoch 11/15
# 989/989 [==============================] - 90s 89ms/step - loss: 0.0752 - accuracy: 0.9788 - val_loss: 0.8018 - val_accuracy: 0.8012
# Epoch 12/15
# 989/989 [==============================] - 90s 89ms/step - loss: 0.0678 - accuracy: 0.9818 - val_loss: 0.8076 - val_accuracy: 0.8006
# Epoch 13/15
# 989/989 [==============================] - 93s 92ms/step - loss: 0.0574 - accuracy: 0.9842 - val_loss: 1.0141 - val_accuracy: 0.7755
# Epoch 14/15
# 989/989 [==============================] - 91s 90ms/step - loss: 0.0526 - accuracy: 0.9863 - val_loss: 0.9918 - val_accuracy: 0.7763
# Epoch 15/15
# 989/989 [==============================] - 88s 86ms/step - loss: 0.0486 - accuracy: 0.9877 - val_loss: 0.9278 - val_accuracy: 0.7814
#
# ### Fold 5 시작 ###
# Epoch 1/15
# 989/989 [==============================] - 92s 86ms/step - loss: 2.9239 - accuracy: 0.4402 - val_loss: 4.2027 - val_accuracy: 0.1969
# Epoch 2/15
# 989/989 [==============================] - 89s 88ms/step - loss: 0.8849 - accuracy: 0.7560 - val_loss: 2.4298 - val_accuracy: 0.3783
# Epoch 3/15
# 989/989 [==============================] - 88s 87ms/step - loss: 0.4052 - accuracy: 0.8812 - val_loss: 1.7274 - val_accuracy: 0.5344
# Epoch 4/15
# 989/989 [==============================] - 90s 88ms/step - loss: 0.2495 - accuracy: 0.9256 - val_loss: 1.3995 - val_accuracy: 0.6104
# Epoch 5/15
# 989/989 [==============================] - 89s 87ms/step - loss: 0.1850 - accuracy: 0.9461 - val_loss: 1.3336 - val_accuracy: 0.6424
# Epoch 6/15
# 989/989 [==============================] - 88s 87ms/step - loss: 0.1412 - accuracy: 0.9584 - val_loss: 1.0616 - val_accuracy: 0.7138
# Epoch 7/15
# 989/989 [==============================] - 89s 88ms/step - loss: 0.1173 - accuracy: 0.9671 - val_loss: 1.0523 - val_accuracy: 0.7333
# Epoch 8/15
# 989/989 [==============================] - 90s 88ms/step - loss: 0.1039 - accuracy: 0.9702 - val_loss: 0.8757 - val_accuracy: 0.7773
# Epoch 9/15
# 989/989 [==============================] - 90s 88ms/step - loss: 0.0865 - accuracy: 0.9759 - val_loss: 0.9269 - val_accuracy: 0.7699
# Epoch 10/15
# 989/989 [==============================] - 89s 87ms/step - loss: 0.0750 - accuracy: 0.9792 - val_loss: 0.9628 - val_accuracy: 0.7589
# Epoch 11/15
# 989/989 [==============================] - 88s 87ms/step - loss: 0.0727 - accuracy: 0.9802 - val_loss: 1.0054 - val_accuracy: 0.7507
# Epoch 12/15
# 989/989 [==============================] - 88s 87ms/step - loss: 0.0596 - accuracy: 0.9846 - val_loss: 1.0801 - val_accuracy: 0.7456
# Epoch 13/15
# 989/989 [==============================] - 88s 87ms/step - loss: 0.0612 - accuracy: 0.9834 - val_loss: 1.0105 - val_accuracy: 0.7652
# Epoch 14/15
# 989/989 [==============================] - 88s 87ms/step - loss: 0.0530 - accuracy: 0.9864 - val_loss: 0.8925 - val_accuracy: 0.7861
# Epoch 15/15
# 989/989 [==============================] - 86s 85ms/step - loss: 0.0544 - accuracy: 0.9851 - val_loss: 0.8402 - val_accuracy: 0.7964
# 테스트 데이터 추론 시작...
# 345/345 [==============================] - 84s 240ms/step
# 추론 완료
# submission.csv 저장 완료
